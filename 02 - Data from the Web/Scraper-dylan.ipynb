# %% [markdown]
# # 02 - Data from the Web
#
#
# ## You will never guess how long it takes EPFL students to complete their degree!
#
# ## Question 2 will shock you!

# %% [markdown]
# ---

# %% [markdown]
# ## Part 0 - Helpers and constants

# %% [markdown]
# #### Import modules

# %%
import requests

from bs4 import BeautifulSoup

import re

import pickle

import pandas as pd

# %% [markdown]
# #### Constants

# %%
# Base URL for isa.epfl.ch public report searches
isa_base_url = 'http://isa.epfl.ch/imoniteur_ISAP/'

# %% [markdown]
# #### Helpers

# %%
# Helper for creating search path
def isa_url(path):
    return isa_base_url + path

# %%
# Allow accessing dictionary items as object attributes
# https://goodcode.io/articles/python-dict-object/
class objdict(dict):
    def __getattr__(self, name):
        if name in self:
            return self[name]
        else:
            raise AttributeError("No such attribute: " + name)

    def __setattr__(self, name, value):
        self[name] = value

    def __delattr__(self, name):
        if name in self:
            del self[name]
        else:
            raise AttributeError("No such attribute: " + name)

# %%
# Fetch the given url using a GET requests with the supplied parameters
# and return a BeautifulSoup object
def get_page(url, params=None):
    r = requests.get(url, params)
    
     # Check whether the request succeeded or not
    if r.status_code is not requests.codes.ok:
        print("Something went wrong. Got status code = %d" % r.status_code)
        return None
    
    # Make sure we actually got some content back, as ISA will return a 200 status code but no content
    # when the supplied parameters are wrong.
    if int(r.headers['Content-Length']) == 0:
        print("Something went wrong. Got Content-Length: 0")
        return None
    
    # Extract the response body
    html = r.text
    
    # Parse it with BeautifulSoup
    return BeautifulSoup(html, 'html.parser')

# %% [markdown]
# ## Part 1 - Scraper Module

# %% [markdown]
# The first step is to fetch all the data from ISA.
#
# To do this, we will have to scrape the respective frames that ISA serves for the form and then the search results. Steps are detailed below.

# %%
# URL of the public ISA home page.
isa_home_url = isa_url('%21gedpublicreports.htm?ww_i_reportmodel=133685247')

# %% [markdown]
# #### Get the right frame URL from the home page

# %%
# Get the home page content
home_soup = get_page(isa_home_url)

# %%
# Find the frame containing the form
toc_frame = home_soup.find('frame', attrs={'name': 'toc'})

# %%
# Extract the frame's URL
toc_frame_url = toc_frame['src']
toc_frame_url
# Out:
# '!GEDPUBLICREPORTS.filter?ww_i_reportModel=133685247'

# %% [markdown]
# #### Let's now get the form itself

# %%
toc_url = isa_url(toc_frame_url)

# %%
toc_soup = get_page(toc_url)

# %%
# Find the form itself within the page.
# The form's name is a heuristic, read from the page's source.
form_elem = toc_soup.find('form', attrs={'name': 'f'})

# %%
# Find the form's action on validation
form_action = form_elem['action']
form_action_url = isa_url(form_action)
form_action_url
# Out:
# 'http://isa.epfl.ch/imoniteur_ISAP/!GEDPUBLICREPORTS.filter'

# %% [markdown]
# ### Manually craft the same request submitting the form would send to the server
#
# The requests below corresponds to:
#
# **Format:** html
# **Unité academique:** Informatique
# **Période académique:** *blank*
# **Période pédagogique:** *blank*
# **Type de semestre:** *blank*

# %%
# Define a payload dictionary with all the parameters expected by ISA's API endpoint

# /!\ By default we will request all possibilities from the endpoint, and then filter. /!\ #

# Example requests for specific academic or pedagogic periods are left FYI.

payload = {
    'ww_b_list': '1',
    'ww_i_reportmodel': '133685247',
    'ww_c_langue': '',
    
    # Format = html
    'ww_i_reportModelXsl': '133685270', 
    
    # Faculty = { Informatique : 249847 }
    'zz_x_UNITE_ACAD': 'Informatique',
    'ww_x_UNITE_ACAD': '249847',
    
    # Academic Period = { '' : null } if we want all possible periods
    #                 = { '2016-2017' : 355925344 } for a specific year
    'zz_x_PERIODE_ACAD': '',
    'ww_x_PERIODE_ACAD': 'null',

    
    # Pedagogic Period = { '' : null } if we want all possible periods
    #                  = { 'Bachelor semestre 1' : 249108 } for a specific period
    'zz_x_PERIODE_PEDAGO': '',
    'ww_x_PERIODE_PEDAGO': 'null',
    
    # Winter or summer semesters
    'zz_x_HIVERETE': '',
    'ww_x_HIVERETE': 'null',
    
    'dummy': 'ok'
}

# %% [markdown]
# #### Send the request and extract the list of links that would appear below the form had we submitted it using the browser

# %%
# Parse the result
form_result_soup = get_page(form_action_url, params=payload)
# form_result_soup.prettify() # Debug print

# %%
# Extract the links from the list of results
all_links = form_result_soup('a', class_='ww_x_GPS')
# all_links # Debug print

# %% [markdown]
# Store the links in a dictionary. Some cleaning is applied, such as whitespace stripping
#
# > **Note:** We remove the first link, named 'Tous', as we will request each page individually
#       in order to avoid downloading a huge HTML table, which would also be much more painful to parse.

# %%
links = [
    objdict({
        'text': link.text.strip(),
        'url': link.attrs['onclick']
    }) for link in all_links if link.text.strip() != 'Tous'
]

# %% [markdown]
# For each link,the page loads the respective results with the following on-click action :
#
# ```
# loadReport('ww_x_GPS=2021043255');return false;
# ```
#
# We will use the following function ```parse_url()``` to extract the ```ww_x_GPS``` parameter expected by the API to return the desired information about the students.

# %%
parse_url_pattern = r"""'(\w+)=(\d+)'"""
parse_url_re = re.compile(parse_url_pattern)

def parse_url(url):
    match = re.search(parse_url_pattern, url)

    if match == None:
        print('parse_url: parsing failure: %s' % url)
        return None
    
    return objdict({
        'key': match.group(1),
        'value': match.group(2)
    })

# %% [markdown]
# The list itself must be parsed to extract information regarding section, academic year, pedagogic period. The format is the following :
#
# ```
# Informatique, 2016-2017, Bachelor semestre 1
# ```
#
# We call an element of the list an item, and it will be parsed by the following ```parse_item()``` function.

# %%
parse_item_pattern = r"""Informatique,\s*(?P<start_year>\d+)-(?P<end_year>\d+),\s*(?P<degree>[\w]+) semestre (?P<semester>\d)"""
parse_item_re = re.compile(parse_item_pattern)

def parse_item(item, url, payload):
    match = re.match(parse_item_re, item)
    
    # The above regex will match only the kind of records we are interested in, so we can
    # safely drop all the non-matching ones
    if match == None:
        # print('Match failed: %s ' % item)
        return None
    
    parsed_url = parse_url(url)
    
    if parsed_url == None:
        return None
    
    params = payload.copy()
    params[parsed_url.key] = parsed_url.value
    
    return objdict({
        'start_year': int(match.group('start_year')),
        'end_year': int(match.group('end_year')),
        'degree': match.group('degree'),
        'semester': int(match.group('semester')),
        'params': params
    })

# Filter all None elements from the given list
def filter_none(a_list):
    return [item for item in a_list if item != None]

# %%
all_items = [parse_item(link.text, link.url, payload) for link in links]

# %%
def is_valid_item(item):
    return item != None and item.start_year >= 2007 and item.end_year <= 2017

def filter_items(items):
    return [item for item in items if is_valid_item(item)]

# %%
items = filter_items(all_items)

# %% [markdown]
# #### Going through the years to extract the list of enrolled students

# %%
list_page_url = isa_url('!GEDPUBLICREPORTS.html')

def parse_student_row(tr, item, headers):
    tds = tr.find_all('td')
    texts = [td.text for td in tds]
    
    res = {}
    for i, header in enumerate(headers):
        res[header] = texts[i]
    
    item_keys = ['degree', 'semester', 'start_year', 'end_year']
    for key in item_keys:
        res[key] = item[key]
    
    return objdict(res)

def parse_students_list(page_soup, item):
    table = page_soup.find('table')
    trs = table.find_all('tr')
    
    if len(trs) < 3:
        return []
    
    (header_row, students_rows) = (trs[1], trs[2:])
        
    headers = [x.text for x in header_row.find_all('th')]
    
    return [
        parse_student_row(student_row, item, headers) for student_row in students_rows
    ]

def load_student_page(item):
    return objdict({
        'soup': get_page(list_page_url, item.params),
        'item': item
    })

def flatten_list(a_list):
    return [item for sublist in a_list for item in sublist]

# TODO: Add logging statements above to see the progress

# %%
load_from_disk = True
save_path = "students_data.p"

if load_from_disk:
    student_list = pickle.load(open(save_path, 'rb'))
else:
    students_pages = [load_student_page(item) for item in items]

    students_lists = [
        parse_students_list(page.soup, page.item) for page in students_pages
    ]

    student_list = flatten_list(students_lists)
    
    # Serialize the whole data to disk
    pickle.dump(student_list, open(save_path, 'wb'))

# %% [markdown]
# ## Part 2 - Data analysis

# %% [markdown]
# ### Question 1
#
# > Keep only the students for which you have an entry for both Bachelor semestre 1 and Bachelor semestre 6. Compute how many months it took each student to go from the first to the sixth semester. Partition the data between male and female students, and compute the average -- is the difference in average statistically significant?

# %%
students_data = pd.DataFrame(student_list)

def load_bsc_data(data):
    bsc_data = students_data[['No Sciper', 'Civilité', 'Nom Prénom', 'degree', 'semester', 'start_year', 'end_year']]
    return bsc_data.rename(columns={'No Sciper': 'sciper', 'Civilité': 'title', 'Nom Prénom': 'name'})
    
bsc_data = load_bsc_data(students_data)

# %%
def filter_bsc_students(bsc_data):
    bsc_students = bsc_data[bsc_data['degree'] == 'Bachelor']
    idx1 = set(bsc_students[bsc_students['semester'] == 1].set_index('sciper').index)
    idx6 = set(bsc_students[bsc_students['semester'] == 6].set_index('sciper').index)

    idx = idx1.intersection(idx6)

    return bsc_students[bsc_students['sciper'].isin(idx)].set_index('sciper').sort_index()

bsc = filter_bsc_students(bsc_data)
bsc
# Out:
#            title                      name    degree  semester  start_year  \
# sciper
# 147008  Monsieur               Good Xavier  Bachelor         4        2009
# 147008  Monsieur               Good Xavier  Bachelor         1        2008
# 147008  Monsieur               Good Xavier  Bachelor         2        2008
# 147008  Monsieur               Good Xavier  Bachelor         3        2009
# 147008  Monsieur               Good Xavier  Bachelor         6        2010
# 147008  Monsieur               Good Xavier  Bachelor         5        2010
# 169569  Monsieur         Arévalo Christian  Bachelor         3        2008
# 169569  Monsieur         Arévalo Christian  Bachelor         4        2008
# 169569  Monsieur         Arévalo Christian  Bachelor         2        2007
# 169569  Monsieur         Arévalo Christian  Bachelor         5        2009
# 169569  Monsieur         Arévalo Christian  Bachelor         6        2009
# 169569  Monsieur         Arévalo Christian  Bachelor         1        2007
# 169731  Monsieur            Knecht Mathieu  Bachelor         5        2010
# 169731  Monsieur            Knecht Mathieu  Bachelor         3        2008
# 169731  Monsieur            Knecht Mathieu  Bachelor         4        2008
# 169731  Monsieur            Knecht Mathieu  Bachelor         3        2009
# 169731  Monsieur            Knecht Mathieu  Bachelor         4        2009
# 169731  Monsieur            Knecht Mathieu  Bachelor         6        2010
# 169731  Monsieur            Knecht Mathieu  Bachelor         1        2007
# 169731  Monsieur            Knecht Mathieu  Bachelor         2        2007
# 169795  Monsieur           Scheiben Pascal  Bachelor         6        2010
# 169795  Monsieur           Scheiben Pascal  Bachelor         5        2011
# 169795  Monsieur           Scheiben Pascal  Bachelor         4        2008
# 169795  Monsieur           Scheiben Pascal  Bachelor         5        2010
# 169795  Monsieur           Scheiben Pascal  Bachelor         5        2009
# 169795  Monsieur           Scheiben Pascal  Bachelor         2        2007
# 169795  Monsieur           Scheiben Pascal  Bachelor         1        2007
# 169795  Monsieur           Scheiben Pascal  Bachelor         6        2009
# 169795  Monsieur           Scheiben Pascal  Bachelor         3        2008
# 171195  Monsieur            Richter Arnaud  Bachelor         4        2008
# ...          ...                       ...       ...       ...         ...
# 250300  Monsieur  Bovel Matthieu Alexandre  Bachelor         5        2016
# 250300  Monsieur  Bovel Matthieu Alexandre  Bachelor         1        2014
# 250300  Monsieur  Bovel Matthieu Alexandre  Bachelor         6        2016
# 250300  Monsieur  Bovel Matthieu Alexandre  Bachelor         4        2015
# 250300  Monsieur  Bovel Matthieu Alexandre  Bachelor         2        2014
# 250300  Monsieur  Bovel Matthieu Alexandre  Bachelor         3        2015
# 250362  Monsieur    Rigori Valentin Joseph  Bachelor         4        2015
# 250362  Monsieur    Rigori Valentin Joseph  Bachelor         3        2015
# 250362  Monsieur    Rigori Valentin Joseph  Bachelor         2        2014
# 250362  Monsieur    Rigori Valentin Joseph  Bachelor         1        2014
# 250362  Monsieur    Rigori Valentin Joseph  Bachelor         6        2016
# 250362  Monsieur    Rigori Valentin Joseph  Bachelor         5        2016
# 250703  Monsieur  Madillo Raphael Frederic  Bachelor         4        2015
# 250703  Monsieur  Madillo Raphael Frederic  Bachelor         3        2015
# 250703  Monsieur  Madillo Raphael Frederic  Bachelor         1        2014
# 250703  Monsieur  Madillo Raphael Frederic  Bachelor         6        2016
# 250703  Monsieur  Madillo Raphael Frederic  Bachelor         2        2014
# 250703  Monsieur  Madillo Raphael Frederic  Bachelor         5        2016
# 251758  Monsieur              Benlalah Ali  Bachelor         3        2015
# 251758  Monsieur              Benlalah Ali  Bachelor         1        2014
# 251758  Monsieur              Benlalah Ali  Bachelor         5        2016
# 251758  Monsieur              Benlalah Ali  Bachelor         6        2016
# 251758  Monsieur              Benlalah Ali  Bachelor         2        2014
# 251758  Monsieur              Benlalah Ali  Bachelor         4        2015
# 251759  Monsieur         Alami-Idrissi Ali  Bachelor         5        2016
# 251759  Monsieur         Alami-Idrissi Ali  Bachelor         6        2016
# 251759  Monsieur         Alami-Idrissi Ali  Bachelor         2        2014
# 251759  Monsieur         Alami-Idrissi Ali  Bachelor         1        2014
# 251759  Monsieur         Alami-Idrissi Ali  Bachelor         4        2015
# 251759  Monsieur         Alami-Idrissi Ali  Bachelor         3        2015
#
#         end_year
# sciper
# 147008      2010
# 147008      2009
# 147008      2009
# 147008      2010
# 147008      2011
# 147008      2011
# 169569      2009
# 169569      2009
# 169569      2008
# 169569      2010
# 169569      2010
# 169569      2008
# 169731      2011
# 169731      2009
# 169731      2009
# 169731      2010
# 169731      2010
# 169731      2011
# 169731      2008
# 169731      2008
# 169795      2011
# 169795      2012
# 169795      2009
# 169795      2011
# 169795      2010
# 169795      2008
# 169795      2008
# 169795      2010
# 169795      2009
# 171195      2009
# ...          ...
# 250300      2017
# 250300      2015
# 250300      2017
# 250300      2016
# 250300      2015
# 250300      2016
# 250362      2016
# 250362      2016
# 250362      2015
# 250362      2015
# 250362      2017
# 250362      2017
# 250703      2016
# 250703      2016
# 250703      2015
# 250703      2017
# 250703      2015
# 250703      2017
# 251758      2016
# 251758      2015
# 251758      2017
# 251758      2017
# 251758      2015
# 251758      2016
# 251759      2017
# 251759      2017
# 251759      2015
# 251759      2015
# 251759      2016
# 251759      2016
#
# [2812 rows x 6 columns]

# %%
def add_semesters_count(bsc):
    cols = ['sciper', 'semester']
    semester_count = bsc.reset_index()[cols].groupby('sciper').count().rename(columns={'semester': 'semester_count'})
    return bsc.merge(semester_count, left_index=True, right_index=True)
    
with_counts = add_semesters_count(bsc)
with_counts.head(20)
# Out:
#            title               name    degree  semester  start_year  end_year  \
# sciper
# 147008  Monsieur        Good Xavier  Bachelor         4        2009      2010
# 147008  Monsieur        Good Xavier  Bachelor         1        2008      2009
# 147008  Monsieur        Good Xavier  Bachelor         2        2008      2009
# 147008  Monsieur        Good Xavier  Bachelor         3        2009      2010
# 147008  Monsieur        Good Xavier  Bachelor         6        2010      2011
# 147008  Monsieur        Good Xavier  Bachelor         5        2010      2011
# 169569  Monsieur  Arévalo Christian  Bachelor         3        2008      2009
# 169569  Monsieur  Arévalo Christian  Bachelor         4        2008      2009
# 169569  Monsieur  Arévalo Christian  Bachelor         2        2007      2008
# 169569  Monsieur  Arévalo Christian  Bachelor         5        2009      2010
# 169569  Monsieur  Arévalo Christian  Bachelor         6        2009      2010
# 169569  Monsieur  Arévalo Christian  Bachelor         1        2007      2008
# 169731  Monsieur     Knecht Mathieu  Bachelor         5        2010      2011
# 169731  Monsieur     Knecht Mathieu  Bachelor         3        2008      2009
# 169731  Monsieur     Knecht Mathieu  Bachelor         4        2008      2009
# 169731  Monsieur     Knecht Mathieu  Bachelor         3        2009      2010
# 169731  Monsieur     Knecht Mathieu  Bachelor         4        2009      2010
# 169731  Monsieur     Knecht Mathieu  Bachelor         6        2010      2011
# 169731  Monsieur     Knecht Mathieu  Bachelor         1        2007      2008
# 169731  Monsieur     Knecht Mathieu  Bachelor         2        2007      2008
#
#         semester_count
# sciper
# 147008               6
# 147008               6
# 147008               6
# 147008               6
# 147008               6
# 147008               6
# 169569               6
# 169569               6
# 169569               6
# 169569               6
# 169569               6
# 169569               6
# 169731               8
# 169731               8
# 169731               8
# 169731               8
# 169731               8
# 169731               8
# 169731               8
# 169731               8

# %%
abc = with_counts[['title', 'name', 'semester_count']].reset_index().groupby('sciper').agg('first')
abc.sample(10)
# Out:
#            title                             name  semester_count
# sciper
# 234523  Monsieur       Breitenstein Yannick Lucas               7
# 228354  Monsieur                      Pires Lucas               6
# 201600  Monsieur              Grütter Karl Samuel               6
# 214293  Monsieur   Grondier Julien François Nizar              11
# 233844    Madame  Hentgen Emily Sandrine Victoria               6
# 224297  Monsieur                 Maillard Mathias               7
# 216451  Monsieur                 Fiszel Ruben Leo               6
# 185811    Madame                   Heldner Céline               6
# 195531  Monsieur                   Gailly Nicolas               8
# 179194  Monsieur                    Obrist Damien               6

# %%
by_title = abc.groupby('title')
by_title['semester_count'].describe()
# Out:
# title
# Madame    count     29.000000
#           mean       6.793103
#           std        1.346406
#           min        6.000000
#           25%        6.000000
#           50%        6.000000
#           75%        8.000000
#           max       11.000000
# Monsieur  count    368.000000
#           mean       7.105978
#           std        1.536891
#           min        4.000000
#           25%        6.000000
#           50%        6.000000
#           75%        8.000000
#           max       12.000000
# Name: semester_count, dtype: float64

# %% [markdown]
# ### Testing the average duration between male (M) and female (F) students

# %%
# Import stats lib for t-test
from scipy import stats

# %% [markdown]
# Let us start by grouping the values into male (M) and female (F) groups

# %%
M = by_title.get_group('Monsieur')['semester_count']
F = by_title.get_group('Madame')['semester_count']

# %% [markdown]
# The mean values are given by :

# %%
print('Mean duration for male students = {}'.format(M.mean()))
print('Mean duration for female students = {}'.format(F.mean()))
# Out:
# Mean duration for male students = 7.105978260869565
# Mean duration for female students = 6.793103448275862

# %% [markdown]
# Though through intuitively we would conclude that the duration is not the same on average, we will conduct a t-test to prove the null hypothesis H0 :
#
# > **H0** -- The mean duration for male and female students is the same

# %% [markdown]
# To test this hypothesis we will use **Welch's t-test**, which is a Student t-test for data with different variances. Welch’s t-test does not pool the standard deviations, but divides the variance in each group by the size of that group. We will have a two-tailed t-test since means can be higher or lower if the null hypothesis is disproved.

# %%
delta_variance = (M.var() - F.var()) # Check that the variances are not equal (justifying Welch's t-test)
tol = 1e-6 # Under this tolerance the difference is not significative

(t_statistic, p_value) = stats.ttest_ind(M, F, equal_var = delta_variance < tol)
print('We find a statistic t = {}, with a p-value = {}'.format(t_statistic, p_value))
# Out:
# We find a statistic t = 1.191705695448116, with a p-value = 0.24162457057331926

# %% [markdown]
# > We have found a high p-value (almost 25%) which means we can reject the null hypothesis and conclude that
# > **there is indeed a difference between the average duration of bachelor study between males and females**.

# %% [markdown]
# ### Question 2
#
# > Perform a similar operation to what described above, this time for Master students. Notice that this data is more tricky, as there are many missing records in the IS-Academia database. Therefore, try to guess how much time a master student spent at EPFL by at least checking the distance in months between Master semestre 1 and Master semestre 2. If the Mineur field is not empty, the student should also appear registered in Master semestre 3. Last but not the least, don't forget to check if the student has an entry also in the Projet Master tables. Once you can handle well this data, compute the "average stay at EPFL" for master students. Now extract all the students with a Spécialisation and compute the "average stay" per each category of that attribute -- compared to the general average, can you find any specialization for which the difference in average is statistically significant?

# %%
def load_msc_data(data):
    cols = [
        'Civilité', 'No Sciper', 'Nom Prénom', 'Statut',
        'Spécialisation', 'Mineur',
        'degree', 'semester', 'end_year', 'start_year'
    ]
    rename = {
        'Civilité': 'title',
        'No Sciper': 'sciper',
        'Nom Prénom': 'name',
        'Statut': 'status',
        'Spécialisation': 'specialisation',
        'Mineur': 'minor'
    }
    
    return students_data[cols].rename(columns=rename)
    
msc_data = load_msc_data(students_data)

def filter_msc_students(students_data):
    return students_data[(students_data['degree'] == 'Master') & (students_data['status'] == 'Présent')]

msc = filter_msc_students(msc_data).set_index('sciper').sort_index()
msc
# Out:
#            title                                               name   status  \
# sciper
# 128911  Monsieur                                     Gulati Asheesh  Présent
# 128911  Monsieur                                     Gulati Asheesh  Présent
# 129093  Monsieur                                         Zhou Maoan  Présent
# 129326  Monsieur                                     Ni Zhong Zhong  Présent
# 129326  Monsieur                                     Ni Zhong Zhong  Présent
# 138088  Monsieur                            Droz-dit-Busset Arnault  Présent
# 145546  Monsieur                               Clivaz Jean-Philippe  Présent
# 145957  Monsieur                                      Hügli Michael  Présent
# 146330  Monsieur                                   Cardinaux Damien  Présent
# 146330  Monsieur                                   Cardinaux Damien  Présent
# 146330  Monsieur                                   Cardinaux Damien  Présent
# 146441    Madame                                   Henriot Laetitia  Présent
# 146742  Monsieur                                       Marx Clément  Présent
# 146742  Monsieur                                       Marx Clément  Présent
# 146742  Monsieur                                       Marx Clément  Présent
# 146742  Monsieur                                       Marx Clément  Présent
# 146742  Monsieur                                       Marx Clément  Présent
# 146752  Monsieur                                   De Lamarter Erik  Présent
# 146929  Monsieur                                      Junod Antoine  Présent
# 146929  Monsieur                                      Junod Antoine  Présent
# 147008  Monsieur                                        Good Xavier  Présent
# 147008  Monsieur                                        Good Xavier  Présent
# 147008  Monsieur                                        Good Xavier  Présent
# 147358  Monsieur                                    Conus Christian  Présent
# 147362  Monsieur                               Rey Charles François  Présent
# 147366  Monsieur                                  Schönmann Patrick  Présent
# 147445  Monsieur                                Robert Pierre-Alain  Présent
# 148900  Monsieur                               Nansi Fabrice Cédric  Présent
# 152232  Monsieur                                 Anagnostaras David  Présent
# 152232  Monsieur                                 Anagnostaras David  Présent
# ...          ...                                                ...      ...
# 268907  Monsieur                                    Dimovski Mladen  Présent
# 268910  Monsieur                                   Hendrikx Hadrien  Présent
# 269057    Madame                                        Zhang Weiyu  Présent
# 269096  Monsieur                              Tomoiaga Ciprian-Ioan  Présent
# 269098  Monsieur                                      Petri Vincent  Présent
# 269369  Monsieur                                 Bhattacharyya Atri  Présent
# 269412  Monsieur                                       Kjosev Tasho  Présent
# 269423    Madame                                      Najdenova Iva  Présent
# 269467  Monsieur                                   Shevchenko Artem  Présent
# 271189  Monsieur                                   Tresch Christian  Présent
# 271331  Monsieur                                   Adams Marc Alain  Présent
# 271711  Monsieur                                  Martinelli Mattia  Présent
# 271965  Monsieur                         Holloway Alexander Patrick  Présent
# 272025    Madame                                     El Zein Yamane  Présent
# 272086    Madame                                         Nie Shiyue  Présent
# 272324  Monsieur                         Colombo Pierre Jean Adrien  Présent
# 272509  Monsieur                                     Sacchi Niccolò  Présent
# 272620  Monsieur                            Gotmare Akhilesh Deepak  Présent
# 272783  Monsieur                      Launay Clément Hervé Stéphane  Présent
# 272785  Monsieur  Le Tourneux De La Perraudiere Valentin Marie Marc  Présent
# 272817    Madame                                Kuziora Marta Kinga  Présent
# 273006    Madame                                          Yin Wensi  Présent
# 273101  Monsieur                                    Adamsons Valdis  Présent
# 273107  Monsieur                        Aquil Mohammad Amimul Ihsan  Présent
# 273118  Monsieur                                   Barbera Antonino  Présent
# 273156  Monsieur                     Champenois Bertrand Brice Marc  Présent
# 273163  Monsieur                         del Marmol Syméon Marie J.  Présent
# 273182  Monsieur                                   Vasiliu Valentin  Présent
# 273251  Monsieur                                       Pavllo Dario  Présent
# 273563    Madame                                        Yiue Ya-Lan  Présent
#
#                         specialisation  \
# sciper
# 128911              Internet computing
# 128911              Internet computing
# 129093
# 129326
# 129326
# 138088
# 145546
# 145957
# 146330
# 146330
# 146330
# 146441
# 146742  Signals, Images and Interfaces
# 146742  Signals, Images and Interfaces
# 146742  Signals, Images and Interfaces
# 146742  Signals, Images and Interfaces
# 146742  Signals, Images and Interfaces
# 146752
# 146929
# 146929
# 147008  Signals, Images and Interfaces
# 147008
# 147008
# 147358
# 147362
# 147366
# 147445
# 148900
# 152232
# 152232
# ...                                ...
# 268907
# 268910
# 269057
# 269096                  Data Analytics
# 269098
# 269369
# 269412
# 269423
# 269467
# 271189
# 271331
# 271711
# 271965
# 272025
# 272086
# 272324
# 272509
# 272620
# 272783
# 272785
# 272817
# 273006
# 273101
# 273107         Foundations of Software
# 273118
# 273156
# 273163
# 273182
# 273251
# 273563
#
#                                                     minor  degree  semester  \
# sciper
# 128911                                                     Master         3
# 128911                                                     Master         2
# 129093                                                     Master         2
# 129326                                                     Master         3
# 129326                                                     Master         2
# 138088                                                     Master         1
# 145546                                                     Master         3
# 145957                                                     Master         3
# 146330                                                     Master         2
# 146330                                                     Master         3
# 146330                                                     Master         1
# 146441                                                     Master         3
# 146742                                                     Master         1
# 146742                                                     Master         3
# 146742                                                     Master         2
# 146742                                                     Master         2
# 146742                                                     Master         3
# 146752                                                     Master         3
# 146929                                                     Master         2
# 146929                                                     Master         1
# 147008                                                     Master         1
# 147008                                                     Master         2
# 147008                                                     Master         3
# 147358                                                     Master         3
# 147362                                                     Master         3
# 147366                                                     Master         3
# 147445                                                     Master         3
# 148900                                                     Master         3
# 152232  Mineur en Management, technologie et entrepren...  Master         3
# 152232                                                     Master         1
# ...                                                   ...     ...       ...
# 268907                                                     Master         1
# 268910                                                     Master         1
# 269057                                                     Master         1
# 269096                                                     Master         1
# 269098                                                     Master         1
# 269369                                                     Master         1
# 269412                                                     Master         1
# 269423                                                     Master         1
# 269467                                                     Master         1
# 271189                                                     Master         1
# 271331                                                     Master         1
# 271711                                                     Master         1
# 271965                                                     Master         1
# 272025                                                     Master         1
# 272086                                                     Master         1
# 272324                                                     Master         1
# 272509                                                     Master         1
# 272620                                                     Master         1
# 272783                                                     Master         1
# 272785                                                     Master         1
# 272817                                                     Master         1
# 273006                                                     Master         1
# 273101                                                     Master         1
# 273107                                                     Master         1
# 273118                                                     Master         1
# 273156                                                     Master         1
# 273163                                                     Master         1
# 273182                                                     Master         1
# 273251                                                     Master         1
# 273563                                                     Master         1
#
#         end_year  start_year
# sciper
# 128911      2008        2007
# 128911      2008        2007
# 129093      2008        2007
# 129326      2008        2007
# 129326      2008        2007
# 138088      2008        2007
# 145546      2008        2007
# 145957      2008        2007
# 146330      2008        2007
# 146330      2009        2008
# 146330      2008        2007
# 146441      2008        2007
# 146742      2009        2008
# 146742      2010        2009
# 146742      2009        2008
# 146742      2010        2009
# 146742      2013        2012
# 146752      2008        2007
# 146929      2008        2007
# 146929      2008        2007
# 147008      2012        2011
# 147008      2012        2011
# 147008      2013        2012
# 147358      2008        2007
# 147362      2008        2007
# 147366      2008        2007
# 147445      2008        2007
# 148900      2008        2007
# 152232      2009        2008
# 152232      2008        2007
# ...          ...         ...
# 268907      2017        2016
# 268910      2017        2016
# 269057      2017        2016
# 269096      2017        2016
# 269098      2017        2016
# 269369      2017        2016
# 269412      2017        2016
# 269423      2017        2016
# 269467      2017        2016
# 271189      2017        2016
# 271331      2017        2016
# 271711      2017        2016
# 271965      2017        2016
# 272025      2017        2016
# 272086      2017        2016
# 272324      2017        2016
# 272509      2017        2016
# 272620      2017        2016
# 272783      2017        2016
# 272785      2017        2016
# 272817      2017        2016
# 273006      2017        2016
# 273101      2017        2016
# 273107      2017        2016
# 273118      2017        2016
# 273156      2017        2016
# 273163      2017        2016
# 273182      2017        2016
# 273251      2017        2016
# 273563      2017        2016
#
# [2398 rows x 9 columns]

# %%
msc_count = add_semesters_count(msc)
msc_count[(msc_count['semester_count'] < 3) & (msc_count['minor'] != '')]
# Out:
#            title                          name   status specialisation  \
# sciper
# 153642  Monsieur                 Imhoff Lionel  Présent
# 153645  Monsieur                  Rosat Damien  Présent
# 160391  Monsieur              Chipounov Vitaly  Présent
# 172257  Monsieur                Dubut Frédéric  Présent
# 199294  Monsieur                   Jin Xuedong  Présent
# 199294  Monsieur                   Jin Xuedong  Présent
# 200419  Monsieur                     Jing Lifu  Présent
# 203301  Monsieur                Nishida Keishi  Présent
# 203301  Monsieur                Nishida Keishi  Présent
# 210271  Monsieur                  Zhang Daiwei  Présent
# 210271  Monsieur                  Zhang Daiwei  Présent
# 225749  Monsieur  Rodrigues Alves Danny Rafael  Présent
# 233800  Monsieur                  Mrini Khalil  Présent
# 237677  Monsieur                Hofer Nataniel  Présent
# 256612  Monsieur        Sympetheros Alexandros  Présent
#
#                                                     minor  degree  semester  \
# sciper
# 153642  Mineur en Management, technologie et entrepren...  Master         3
# 153645  Mineur en Management, technologie et entrepren...  Master         3
# 160391  Mineur en Management, technologie et entrepren...  Master         3
# 172257  Mineur en Management, technologie et entrepren...  Master         3
# 199294  Mineur en Management, technologie et entrepren...  Master         2
# 199294  Mineur en Management, technologie et entrepren...  Master         3
# 200419  Mineur en Management, technologie et entrepren...  Master         2
# 203301  Mineur en Management, technologie et entrepren...  Master         2
# 203301  Mineur en Management, technologie et entrepren...  Master         1
# 210271  Mineur en Management, technologie et entrepren...  Master         1
# 210271  Mineur en Management, technologie et entrepren...  Master         2
# 225749  Mineur en Management, technologie et entrepren...  Master         1
# 233800                                  Mineur STAS Chine  Master         1
# 237677          Mineur en Neurosciences computationnelles  Master         1
# 256612  Mineur en Management, technologie et entrepren...  Master         2
#
#         end_year  start_year  semester_count
# sciper
# 153642      2008        2007               1
# 153645      2008        2007               1
# 160391      2008        2007               1
# 172257      2008        2007               1
# 199294      2011        2010               2
# 199294      2012        2011               2
# 200419      2011        2010               2
# 203301      2011        2010               2
# 203301      2011        2010               2
# 210271      2012        2011               2
# 210271      2012        2011               2
# 225749      2017        2016               2
# 233800      2017        2016               1
# 237677      2017        2016               1
# 256612      2016        2015               2

# %%
msc_agg = msc_count[['title', 'name', 'minor', 'specialisation', 'semester_count']].reset_index().groupby('sciper').agg('first')
msc_agg.sample(10)
# Out:
#            title                                         name minor  \
# sciper
# 248065  Monsieur                   Hilloulin Damien Alexandre
# 205932  Monsieur                        Ichim Alexandru Eugen
# 225654    Madame                                  Aeby Prisca
# 271331  Monsieur                             Adams Marc Alain
# 213186  Monsieur                  Eslier Thomas François Alex
# 213618  Monsieur  Amorim Afonso Caldeira Da Silva Pedro Maria
# 201689  Monsieur                 Francois Arthur Alain Albert
# 181419    Madame                       Triponez Elodie Nilane
# 228197    Madame                            Gucevska Natalija
# 186264  Monsieur                               Bougacha Malik
#
#                       specialisation  semester_count
# sciper
# 248065                                             3
# 205932                                             2
# 225654  Internet Information Systems               3
# 271331                                             1
# 213186                                             2
# 213618                                             3
# 201689                                             3
# 181419                                             3
# 228197                                             1
# 186264                                             4

# %% [markdown]
# #### Average stay at EPFL for master students

# %%
msc_agg = msc_agg[msc_agg['semester_count'] >= 1]
avg_stay_masters = msc_agg.mean()
print('The average stay for masters students at EPFL is {} semesters'.format(avg_stay_masters['semester_count']))
# Out:
# The average stay for masters students at EPFL is 2.4849740932642486 semesters

# %% [markdown]
# #### Average stay per specialisation
# find any specialization for which the difference in average is statistically significant

# %%
msc_spe = msc_agg[['specialisation', 'semester_count']].groupby('specialisation').agg('mean').rename(columns={'semester_count':'mean_stay'})
msc_spe['mean_stay']
# Out:
# specialisation
#                                   2.365952
# Biocomputing                      1.727273
# Computer Engineering - SP         3.133333
# Data Analytics                    2.285714
# Foundations of Software           2.963636
# Information Security - SP         3.166667
# Internet Information Systems      3.000000
# Internet computing                2.962500
# Service science                   3.333333
# Signals, Images and Interfaces    2.933333
# Software Systems                  2.818182
# Name: mean_stay, dtype: float64

# %% [markdown]
# To find statistical differences in this means we will use an F-test for one-way ANOVA, with the null hypothesis H0
# > H0 -- The mean stay for all specialisations is the same

# %% [markdown]
# We will assume the following hypotheses to be true :
# * Each population is normally distributed
# * Independent samples from the populations
# * Equal population standard deviations

# %%
msc_spe = msc_agg.reset_index()[['specialisation', 'semester_count']].set_index('specialisation').sort_index()
# msc_spe # This is indexed by specialisation and has all the semester counts. Tried grouping with 'specialisation', ag

# %%
msc_spe_gp = msc_agg.reset_index()[['specialisation', 'semester_count']].groupby('specialisation')
msc_gp = [msc_spe_gp.get_group(g)['semester_count'] for g in msc_spe_gp.groups]

# %%
# TODO ! Check, not 100% sure it works ...
# spe1 = [n_semesters1, n_semesters2, ...]
# stats.f_oneway(spe1, spe2, ...)
stats.f_oneway(*msc_gp) # equivalent to apply(stats.f_oneway, *args)
# Out:
# F_onewayResult(statistic=6.847975896335007, pvalue=2.1772271455000516e-10)

# %% [markdown]
# ### Bonus
# > Perform the gender-based study also on the Master students, as explained in 1. Use scatterplots to visually identify changes over time. Plot males and females with different colors -- can you spot different trends that match the results of your statistical tests?

# %%
msc = msc_count[['title', 'name', 'semester_count']].reset_index().groupby('sciper').agg('first')
msc_by_title = msc.groupby('title')
msc_by_title['semester_count'].describe()
# Out:
# title
# Madame    count    131.000000
#           mean       2.503817
#           std        1.098069
#           min        1.000000
#           25%        2.000000
#           50%        3.000000
#           75%        3.000000
#           max        7.000000
# Monsieur  count    834.000000
#           mean       2.482014
#           std        1.004330
#           min        1.000000
#           25%        2.000000
#           50%        3.000000
#           75%        3.000000
#           max        6.000000
# Name: semester_count, dtype: float64

# %%
M_msc = msc_by_title.get_group('Monsieur')['semester_count']
F_msc = msc_by_title.get_group('Madame')['semester_count']

# %%
print('Mean duration for male students = {}'.format(M_msc.mean()))
print('Mean duration for female students = {}'.format(F_msc.mean()))
# Out:
# Mean duration for male students = 2.4820143884892087
# Mean duration for female students = 2.50381679389313

# %%
delta_variance = (M_msc.var() - F_msc.var()) # Check that the variances are not equal (justifying Welch's t-test)
tol = 1e-6 # Under this tolerance the difference is not significative

(t_statistic_msc, p_value_msc) = stats.ttest_ind(M_msc, F_msc, equal_var = delta_variance < tol)
print('We find a statistic t = {}, with a p-value = {}'.format(t_statistic_msc, p_value_msc))
# Out:
# We find a statistic t = -0.22799730652686717, with a p-value = 0.8196967344880302
